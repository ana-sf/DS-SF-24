# %%
import sklearn
import seaborn

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/ga-students/DS-SF-24/master/Data/AdvertisingCleaned"
AdData = pd.read_csv(url)
AdData.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
del AdData['Unnamed: 0']

# %% [markdown]
# #### AdData is an outlier free dataset. We took care of outliers in previous lecture.
# sales in thousands of units
#
# budgets in thousands of dollars (For instance TV =5 means 5000 dollars budget in TV ads)
#
# 200 different markets. After removing outliers we are left with 198 observations.

# %%
AdData.corr()  #Correlation Matrix
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.051978   0.049771  0.779121
# Radio      0.051978  1.000000   0.346364  0.576748
# Newspaper  0.049771  0.346364   1.000000  0.219555
# Sales      0.779121  0.576748   0.219555  1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(AdData.TV, AdData.Sales)
plt.xlabel("TV Adds in Thousand Dollars")
plt.ylabel("Sales in Thousand Units")
plt.show()

# %% [markdown]
# #### seaborn
# Seaborn is another great and useful visualization library. This library is really useful for linear regression models. Please refer to [Seaborn](https://web.stanford.edu/~mwaskom/software/seaborn/api.html) API reference.

# %%
import seaborn as sns   #seaborn
sns.regplot(AdData.TV, AdData.Sales)
plt.show()

# %% [markdown]
# In the diagram above:
#
# - The blue dots are the **Observed Values**
# - The blue line is your one-variable regression line
# - The shaded area around your regression line is your confidence interval for the average predicted  values.

# %% [markdown]
# #### Bonus Material - Residual Plot

# %%
sns.residplot(AdData.TV, AdData.Sales) #residual plot shows the error in your predicted value based on your input. 
plt.show() #the error is random as it should be. however, the spread of variance around the residual line seems to 
#increase over time.

# %% [markdown]
# We better not see any pattern in residual plot. The above graph is suffering from a problem called [heteroskedasticity](http://www.statsmakemecry.com/smmctheblog/confusing-stats-terms-explained-heteroscedasticity-heteroske.html) - say that fast three times in a row :)
#
# This problem can be solved by using [Weighted Least Square (WLS)](http://www.econ.uiuc.edu/~wsosa/econ471/GLSHeteroskedasticity.pdf) method.

# %% [markdown]
# ## Now let's build a regression line (Import, Instantiate, Fit)

# %% [markdown]
# From today on, almost every lecture, we are going to refer to [scikit-learn](http://scikit-learn.org/stable/) library.

# %%
from sklearn.linear_model import LinearRegression  #import

# %%
linreg = LinearRegression() #Instantiate

# %% [markdown]
# #### Create X (your inputs) and Y ( your output)
#
# Let's investigate the relationship between TV (input) and Sales (output)

# %%
X = AdData[['TV']]   #Matrix of Input -- separate vars by commas. use caps for inputs. 
y= AdData['Sales']   #Output

# %%
linreg.fit(X,y)     #Fit
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Let's print intercept and slope
print('Our intercept is %f' %linreg.intercept_)
print("Our slope is %f" %linreg.coef_)
# Out:
# Our intercept is 7.030561
# Our slope is 0.047381

# %% [markdown]
# Our Linear Regression Line is:
# Sales_hat = 7.03056 + 0.04738 * TV
#
# In other words, for every thousand dollars expenditure on TV ads - everything else fixed, you can expect increase of 47 units in Sales. Be careful, *this does not necessarily suggest causation!*

# %% [markdown]
# # Now let's use our linear model to make predictions.
#
# First, be very careful! Most of the models are only capable to be used for prediction within the range of data you trained your algorithms by. Let's explore the *min* and the *max* of TV data.

# %%
AdData['TV'].describe()
# Out:
# count    198.000000
# mean     146.688384
# std       85.443221
# min        0.700000
# 25%       74.800000
# 50%      149.750000
# 75%      218.475000
# max      293.600000
# Name: TV, dtype: float64

# %% [markdown]
# Based on the above summary - we can solely make predictions within the range of observed data. For instance, the lowest amount of expenditure in TV ads is (.7) 700 dollars and the highest figure is (293.6) 293600 dollars. We may be able to predict slightly below or above the range, but it is not a good idea to make predictions for values so much below or above your available data. This is called extrapolation.

# %% [markdown]
# Let's predict how much is the average Sales of a company that spends 100,000 dollars in TV ads.

# %%
print(linreg.predict(100))
# Out:
# [ 11.76866439]

# %% [markdown]
# Based on our model, such a company sells on average 11768 (11769) units.

# %% [markdown]
# #### Now let's use Radio and TV as input variables.

# %%
X = AdData[['TV','Radio']]
y= AdData['Sales']
linreg.fit(X,y)
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 2.93147585094
# [ 0.04568137  0.18799199]

# %%
# You can use zip([List 1 or Array 1],[List 2 or Array 2]) to make outputs easier to interpret
print(zip(['TV','Radio'], linreg.coef_))
# Out:
# [('TV', 0.045681365065253984), ('Radio', 0.18799198894046995)]

# %%
print("Our Linear Regression Model is:")
print("Sales_hat = %f + %f * TV_ads + %f * Radio_ads" % (linreg.intercept_, 
      linreg.coef_[0] ,linreg.coef_[1]))
# Out:
# Our Linear Regression Model is:
# Sales_hat = 2.931476 + 0.045681 * TV_ads + 0.187992 * Radio_ads

# %% [markdown]
# In our data set - keeping everything else fixed - every 1000 dollars expenditure on TV ads, on average contributed to 45.68 units of Sales and every 1000 dollars expenditure on Radio, contributed 188 units to Sales. Does it mean Radio ads contribute to Sales more than TV ads? (DON'T JUMP INTO CONCLUSIONS THAT FAST)
#
# Again, please be careful, we are not suggesting causation. Moreover, we assumed everything is fixed when interpreted TV and Radio ads. In reality, companies who spend on TV ads tend to also spend on other means of ad.

# %%
AdData['Radio'].describe() #Let's explore Radio Data
# Out:
# count    198.000000
# mean      23.130808
# std       14.862111
# min        0.000000
# 25%        9.925000
# 50%       22.400000
# 75%       36.325000
# max       49.600000
# Name: Radio, dtype: float64

# %% [markdown]
# First of all, we just observed that in comparison to TV ads, only little has been spent on Radio ads. Median expenditure on TV ads is 7 times more than Radio ads. Second, may be only those companies who spend a lot in TV are interested in spending money in Radio ads. Let's explore it with a scatterplot.

# %%
#AdData.plot(kind= 'scatter', x = 'TV',y = 'Radio')
plt.scatter(AdData['TV'], AdData['Radio'])
plt.xlabel('TV Ad Expenditure')
plt.ylabel('Radio Ad Expenditure')
plt.show()

# %% [markdown]
# Fortunately, the scatter plot does not suggest that much of association between TV ads and Radio ads. That's good! Actually, corr() matrix suggested that there were no linear relationship.

# %% [markdown]
# #### So, how can we interpret the results?
#
# May be there is synergy between TV and Radio. In other words, may be, Radio ads are effective only if we have spent enough in TV and visa-versa. In marketing, it is being said that an ad is effective if a potential customer is exposed to it at least 5 times. So, synergy effect is yet to be tested! This is what we are going to explore next session. Also, may be the types of businesses who spend money on TV are completely different from those who spend money on Radio ads.

# %% [markdown]
# # Bonus Graph!
# Contour maps can display information about a function of two variables without reference to a surface. [Here](http://math.arizona.edu/~calc/Text/Section12.3.pdf) Contours are elegantly introduced.

# %%
sns.interactplot(AdData['TV'], AdData['Radio'], AdData['Sales'])
plt.show()

# %% [markdown]
# #### What is your prediction for a company that has spent 150000 dollars on TV ads and 30000 on Radio ads?

# %%
print(linreg.predict([[150,30]]))  #we predict 15423 units
# Out:
# [ 15.42344028]

# %% [markdown]
# ** This was just a demo. Very important assumptions were not checked in this study. For example we did not check p-values, significantly of variables, Error, and confidence interval of our predictions and coefficients. We also did not check synergy effects. All of these very important topics will be covered in our next lecture. **
